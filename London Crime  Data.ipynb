# %%
import numpy
import os
from google.cloud import bigquery
from pandas.io import gbq
import bq_helper

os.environ['GOOGLE_APPLICATION_CREDENTIALS']='/Users/khrystynakopachevska/downloads/Big Data-1aed7559ebc4.json'

# %%
client = bigquery.Client()
hn_dataset_ref = client.dataset('london_crime', project='bigquery-public-data')
hn_dset=client.get_dataset(hn_dataset_ref)
crime=bq_helper.BigQueryHelper(active_project='bigquery-public-data', dataset_name='london_crime')

# %%
QUERY = """
SELECT borough, year, sum(value) as number
FROM `bigquery-public-data.london_crime.crime_by_lsoa`
group by borough, year
order by number DESC;
"""
df=crime.query_to_pandas_safe(QUERY)

# %%
# %matplotlib inline

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
from numpy import random, float
from numpy import random, array

boroughs = df['borough']
values = df['number']
boroughArray=numpy.asarray(boroughs)
valuesArray =numpy.asarray(values)

# %%
model = KMeans(n_clusters=32)

plt.figure(figsize=(45, 20))
plt.scatter(boroughArray, valuesArray)
plt.show()
